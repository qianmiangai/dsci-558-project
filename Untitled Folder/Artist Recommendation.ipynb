# %%
import pandas as pd
import spacy
from collections import defaultdict, Counter
from tqdm.notebook import tqdm
import numpy as np
import pickle

# %%
df = pd.read_csv("../Final_Streamlit/data/Final_Dataset_w_colorgroup.csv")

# %%
artist_linking_df = pd.read_csv("../EntityLinking/data/artist_predictions.csv")

# %%
artist_linking_df.head()
# Out:
#    Artsy  Widewalls       artist_name
# 0      2        281  Roy Lichtenstein
# 1     12       2260   Josep Guinovart
# 2     13        103     Macha Poynder
# 3     36       1954    Eddie Martinez
# 4     37       1826       Louis Masai

# %%
target_artists = artist_linking_df['artist_name'].tolist()

# %%
full_bio_df = pd.read_csv("../Scrape/Widewalls/data/CleanedWidewallsData.csv")

# %%
target_full_bio_df = full_bio_df[full_bio_df['artist_names'].isin(target_artists)]

# %%
target_full_bio_df.head()
# Out:
#        artist_names                                          full_bios  id
# 1    David Shrigley  David Shrigley is a Glasgow-based British arti...   2
# 4      David Yarrow  An artist followed by an amazing reputation fo...   5
# 6   Dan Christensen  Dan Christensen was an American abstract paint...   7
# 10             KAWS  In the late ’80s and early ’90s, the interesti...  11
# 18      Andy Warhol  It was the beginning of the 1950s when the art...  19

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def build_artist_profile(artist_profiles, artist_name, full_bio):
    doc = nlp(full_bio)
    def tag_entity(entity):
        if entity.label_ == "ORG":
            if "university" in entity.text.lower() or "school" in entity.text.lower()\
            or "masters" in entity.text.lower() or "institute" in entity.text.lower():
                return "EDUCATION"
        if entity.label_ == "NORP":
            return "NATIONALITY"
        if entity.label_ == "GPE":
            return "LOCATION BASE"
        else:
            return None
    
    locations = []
    has_first_norp = False
    for entity in doc.ents:
        tag = tag_entity(entity)
        if tag:
    #         print(entity.text, entity.label_, tag)
            if tag == "NATIONALITY" and not has_first_norp:
                artist_profiles[artist_name]['nationality'] = entity.text
                has_first_norp = True
            if tag == "EDUCATION":
                artist_profiles[artist_name]['education'] = entity.text
            if tag == "LOCATION BASE":
                locations.append(entity.text)
    if len(locations)>0:
        c = Counter(locations)
        location_base = list(c.most_common())[0][0]
        artist_profiles[artist_name]['location'] = location_base
    if 'nationality' not in artist_profiles[artist_name]:
        artist_profiles[artist_name]['nationality'] = np.NaN
    if 'education' not in artist_profiles[artist_name]:
        artist_profiles[artist_name]['education'] = np.NaN
    if 'location' not in artist_profiles[artist_name]:
        artist_profiles[artist_name]['location'] = np.NaN
    return 
#         print(entity.text, entity.label_)

# %%
artist_profiles = defaultdict(dict)
i = 0
for _, name, bio, _ in tqdm(target_full_bio_df.itertuples(), total=len(full_bio_df)):
    
    if isinstance(name, str) and isinstance(bio, str) and len(bio) > 10:
        try:
            build_artist_profile(artist_profiles, name, bio)
        except e:
            print(name)
        i += 1
# Out:
#   0%|          | 0/2534 [00:00<?, ?it/s]

# %%
len(artist_profiles)
# Out:
# 500

# %%
len(target_full_bio_df)
# Out:
# 500

# %%
artist_profiles
# Out:
# defaultdict(dict,
#             {'David Shrigley': {'nationality': 'British',
#               'location': 'Glasgow',
#               'education': nan},
#              'David Yarrow': {'education': 'the Edinburgh University',
#               'nationality': 'British',
#               'location': 'Glasgow'},
#              'Dan Christensen': {'nationality': 'American',
#               'education': 'the\xa0Kansas City Art Institute',
#               'location': 'Denver'},
#              'KAWS': {'nationality': 'American',
#               'education': 'the School of Visual Arts',
#               'location': 'Tokyo'},
#              'Andy Warhol': {'nationality': 'American',
#               'education': 'Carnegie-Mellon University',
#               'location': 'New York'},
#              'Hunter & Gatti': {'nationality': nan,
#               'education': nan,
#               'location': nan},
#              'Leslie Sheryll': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Pablo Picasso': {'nationality': 'Spanish',
#               'education': 'the School of Fine Arts',
#               'location': 'Paris'},
#              'Mel Ramos': {'nationality': 'American',
#               'education': 'California State University',
#               'location': 'Sacramento'},
#              "Terry O'Neill": {'nationality': 'English',
#               'education': nan,
#               'location': nan},
#              'Josef Albers': {'nationality': 'German',
#               'education': 'the Rochester Institute of Technology',
#               'location': 'Bottrop'},
#              'Thomas Ruff': {'nationality': 'German',
#               'location': 'New York',
#               'education': nan},
#              'Margaret Morrison': {'nationality': 'American',
#               'education': 'the University of Georgia',
#               'location': 'Utah'},
#              'Robert Indiana': {'nationality': 'American',
#               'education': 'the Skowhegan School of Sculpture and Painting in Maine',
#               'location': 'Indiana'},
#              'John Van Alstine': {'nationality': 'American',
#               'education': 'the University of Maryland in College Park',
#               'location': 'Laramie'},
#              'Damien Hirst': {'nationality': 'British',
#               'education': 'Leeds Medical School',
#               'location': nan},
#              'Peter Max': {'nationality': 'German',
#               'education': 'Lafayette High School',
#               'location': 'Israel'},
#              'Mr. Brainwash': {'nationality': 'Invader',
#               'location': 'Los Angeles',
#               'education': nan},
#              'Alex Katz': {'nationality': 'American',
#               'education': "Pratt Institute's",
#               'location': 'New York'},
#              'Jeff Koons': {'nationality': 'American',
#               'education': 'the Art Institute',
#               'location': 'New York'},
#              'Alexander Calder': {'nationality': 'American',
#               'education': 'the Stevens Institute of Technology',
#               'location': 'New York'},
#              'Macha Poynder': {'nationality': 'Russian',
#               'location': 'Paris',
#               'education': nan},
#              'Roberto Matta': {'nationality': 'European',
#               'location': 'Matta',
#               'education': nan},
#              'Matt Mullican': {'nationality': 'American',
#               'education': 'The London Institute',
#               'location': 'Germany'},
#              'Mark Kostabi': {'nationality': 'American',
#               'education': 'California State University',
#               'location': 'Rome'},
#              'Shepard Fairey': {'nationality': 'American',
#               'education': 'the Institute of Contemporary Art',
#               'location': 'Obama'},
#              'James Rosenquist': {'nationality': 'Swedish',
#               'education': 'the American Academy and Institute of Art and Letters',
#               'location': 'New York'},
#              'Marc Chagall': {'nationality': 'Belorussian',
#               'education': 'The Art Institute of Chicago',
#               'location': 'Chagall'},
#              'Keith Haring': {'nationality': 'American',
#               'education': 'the School of Visual Art',
#               'location': 'New York City'},
#              'Carroll Dunham': {'nationality': 'Surrealism',
#               'education': 'the Art Institute of Chicago',
#               'location': 'New York'},
#              'Deborah Kass': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Terry Winters': {'nationality': 'American',
#               'education': 'Pratt Institute',
#               'location': 'Brooklyn'},
#              'Daniel Arsham': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'David Hockney': {'nationality': 'English',
#               'location': 'Hockney',
#               'education': nan},
#              'Wolf Kahn': {'nationality': 'Nazi',
#               'education': 'the University of Chicago',
#               'location': 'New York'},
#              'Donald Sultan': {'nationality': 'Sultan',
#               'education': 'the Corcoran School of Art',
#               'location': 'New York'},
#              'Robert Rauschenberg': {'nationality': 'American',
#               'education': 'the Kansas City Art Institute',
#               'location': 'New York'},
#              'Peter Doig': {'nationality': 'Scottish',
#               'education': 'the Chelsea School of Art',
#               'location': 'London'},
#              'Sunday B. Morning': {'nationality': 'Belgians',
#               'education': nan,
#               'location': nan},
#              'Tony Tasset': {'nationality': 'American',
#               'education': 'the University of Illinois at Chicago',
#               'location': 'Cincinnati'},
#              'Richard Caldicott': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Paola Pivi': {'nationality': 'Italian',
#               'location': 'Milan',
#               'education': nan},
#              'Arman': {'nationality': 'French',
#               'location': 'Nice',
#               'education': nan},
#              'Tracey Adams': {'nationality': 'American',
#               'education': 'the School of the Museum of Fine Arts',
#               'location': 'Boston'},
#              'Troika': {'education': 'The Art Institute of Chicago',
#               'location': 'London',
#               'nationality': nan},
#              'Mel Bochner': {'nationality': 'American',
#               'education': 'the School of Visual Arts',
#               'location': 'Bochner'},
#              'David Drebin': {'nationality': 'Canadian',
#               'education': 'the Parsons School of Design',
#               'location': 'New York'},
#              'Dean West': {'nationality': 'Australian',
#               'location': 'New York',
#               'education': nan},
#              'Jose Ricardo Contreras Gonzalez': {'nationality': 'Colombian',
#               'education': nan,
#               'location': nan},
#              'Banksy': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Yoshitomo Nara': {'nationality': 'Japanese',
#               'education': 'Aichi Prefectural University of Fine Arts',
#               'location': 'Japan'},
#              'Joe Tilson': {'nationality': 'English',
#               'location': 'London',
#               'education': nan},
#              'Tracey Emin': {'nationality': 'British',
#               'education': 'Birkbeck, University of London',
#               'location': 'London'},
#              'Nick Veasey': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'On Hansen': {'nationality': 'Scandinavian',
#               'education': nan,
#               'location': nan},
#              'LeRoy Neiman': {'nationality': 'American',
#               'education': 'Columbia University',
#               'location': 'Neiman'},
#              'Richard Anuszkiewicz': {'nationality': 'American',
#               'education': 'Masters of Fine Arts',
#               'location': 'Cleveland'},
#              'Larry Rivers': {'nationality': 'American',
#               'education': 'New York University',
#               'location': 'New York'},
#              'Jessica Snow': {'nationality': 'American',
#               'education': 'the Skowhegan School of Painting and Sculpture',
#               'location': 'Berkeley'},
#              'Roy Lichtenstein': {'nationality': 'American',
#               'education': 'New York University Medical Center',
#               'location': 'Lichtenstein'},
#              'Sam Francis': {'nationality': 'American',
#               'education': 'the University of California Press',
#               'location': 'Japan'},
#              'Dennis Oppenheim': {'nationality': 'American',
#               'education': 'Cornell University',
#               'location': 'New York'},
#              'Sandro Chia': {'nationality': 'Italian',
#               'location': 'Italy',
#               'education': nan},
#              'Martina Nehrling': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Brooke Noel Morgan': {'location': 'Nashville',
#               'nationality': nan,
#               'education': nan},
#              'Nathan Sawaya': {'education': 'the New York University',
#               'nationality': 'Surrealism',
#               'location': 'DC'},
#              'Allen Jones': {'nationality': 'British',
#               'education': 'the Chelsea School of Art',
#               'location': 'London'},
#              'Atelier Van Lieshout': {'location': 'Amsterdam',
#               'nationality': nan,
#               'education': nan},
#              'Bharti Kher': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Elena Bulatova': {'education': 'Yale University',
#               'nationality': 'Russian',
#               'location': 'Palm Springs'},
#              'Robert Motherwell': {'nationality': 'American',
#               'education': 'the New York School',
#               'location': 'Washington'},
#              'Jim Dine': {'education': 'Ohio University',
#               'location': 'America',
#               'nationality': nan},
#              'Luigi Ghirri': {'nationality': 'Italian',
#               'location': 'New York City',
#               'education': nan},
#              'Greg Beebe': {'location': 'Miami',
#               'nationality': nan,
#               'education': nan},
#              'Invader': {'nationality': 'Invader',
#               'location': 'London',
#               'education': nan},
#              'Kenny Scharf': {'education': 'the School of Visual Arts',
#               'nationality': 'Groovenians',
#               'location': 'New York'},
#              'Paul Jenkins': {'nationality': 'American',
#               'education': 'Kansas City Art Institute',
#               'location': 'New York'},
#              'Johan Creten': {'nationality': 'Flemish',
#               'education': 'the School of Fine Arts',
#               'location': 'Sint-Truiden'},
#              'Ian McKeever': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Efren Isaza': {'nationality': 'Colombian',
#               'education': nan,
#               'location': nan},
#              'Mattia Bosco': {'nationality': 'Italian',
#               'education': nan,
#               'location': nan},
#              'Yaacov Agam': {'nationality': 'Hebrew',
#               'location': 'Paris',
#               'education': nan},
#              'Victor Vasarely': {'nationality': 'Hungarian',
#               'education': 'the University of Caracas',
#               'location': 'Paris'},
#              'Takashi Murakami': {'nationality': 'Japanese',
#               'education': 'The University of Tokyo',
#               'location': 'Murakami'},
#              'Yayoi Kusama': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Greet Helsen': {'nationality': 'Belgian',
#               'education': 'the Assenza Visual Art School',
#               'location': 'Switzerland'},
#              'Corneille': {'nationality': 'Dutch',
#               'education': nan,
#               'location': nan},
#              'Pierre Alechinsky': {'nationality': 'Belgian',
#               'education': 'Nova Southeastern University',
#               'location': 'Schaerbeek'},
#              'Elizabeth Peyton': {'education': 'the School of Visual Arts',
#               'location': 'Peyton',
#               'nationality': nan},
#              'Karel Appel': {'nationality': 'Dutch',
#               'location': 'Karel',
#               'education': nan},
#              'Albert Watson': {'nationality': 'Scottish',
#               'location': 'Vogue',
#               'education': nan},
#              'Jason Middlebrook': {'nationality': 'American',
#               'education': 'State University',
#               'location': 'NY'},
#              'Menashe Kadishman': {'nationality': 'Israeli',
#               'location': 'Tel Aviv',
#               'education': nan},
#              'Stanley Whitney': {'nationality': 'American',
#               'education': 'the Tyler School of Art, Temple University',
#               'location': 'New York'},
#              'Chris Ofili': {'nationality': 'English',
#               'education': 'the Chelsea School of Art',
#               'location': 'London'},
#              'Bernard Buffet': {'nationality': 'French',
#               'education': 'National School of the Fine Arts',
#               'location': 'Paris'},
#              'Onemizer': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Beverly Fishman': {'nationality': 'American',
#               'education': 'Yale University',
#               'location': 'Detroit'},
#              'Koenraad Dedobbeleer': {'nationality': 'Belgian',
#               'location': 'Brussels',
#               'education': nan},
#              'Matt Shlian': {'nationality': 'American',
#               'education': 'Alfred University',
#               'location': 'Norwalk'},
#              'Ann Gardner': {'nationality': 'American',
#               'location': 'Seattle',
#               'education': nan},
#              'Virgil Abloh': {'nationality': 'American',
#               'education': 'the Illinois Institute of Technology',
#               'location': 'Architecture'},
#              'Cameron Platter': {'nationality': 'South African',
#               'location': 'New York MoMA',
#               'education': nan},
#              'Dale Chihuly': {'nationality': 'American',
#               'education': 'Pilchuck Glass School',
#               'location': 'Venice'},
#              'Ellsworth Kelly': {'nationality': 'Minimalist',
#               'education': 'the School of the Museum of Fine Arts',
#               'location': 'New York'},
#              'Red Grooms': {'nationality': 'American',
#               'education': 'the University of New Mexico',
#               'location': 'Nashville'},
#              'Robert Natkin': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Henri Matisse': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Jaume Plensa': {'nationality': 'Spanish',
#               'education': 'the University of Michigan Museum of Art',
#               'location': 'France'},
#              'Enrico Baj': {'nationality': 'Italian',
#               'education': nan,
#               'location': nan},
#              'Pedro Cabrita Reis': {'location': 'Portugal',
#               'nationality': nan,
#               'education': nan},
#              'Agent X': {'nationality': 'American',
#               'location': 'Vancouver',
#               'education': nan},
#              'Nicolas Party': {'nationality': 'American',
#               'education': 'Glasgow School of Art',
#               'location': 'New York'},
#              'Swoon': {'education': 'the Pratt Institute',
#               'nationality': 'Toyshop',
#               'location': 'Brooklyn'},
#              'Ai Weiwei': {'nationality': 'Chinese',
#               'education': 'the Parsons School of Design',
#               'location': 'Beijing'},
#              'Robert Mapplethorpe': {'nationality': 'American',
#               'education': 'Institute',
#               'location': 'Mapplethorpe'},
#              'Tom Wesselmann': {'nationality': 'American',
#               'education': 'the High School of Art and Design',
#               'location': 'New York'},
#              'Wifredo Lam': {'nationality': 'Chinese',
#               'education': 'Havana University',
#               'location': 'Paris'},
#              'Patrick Wilson': {'nationality': 'American',
#               'education': 'Claremont Graduate School in Claremont',
#               'location': 'California'},
#              'Hamish Fulton': {'nationality': 'Native American',
#               'education': "Saint Martin's School of Art",
#               'location': 'Fulton'},
#              'Joan Witek': {'nationality': 'American',
#               'education': 'Harvard University',
#               'location': 'USA'},
#              'Ed Ruscha': {'nationality': 'American',
#               'education': 'the Getty Research Institute',
#               'location': 'Hollywood'},
#              'John Baldessari': {'nationality': 'American',
#               'education': 'Otis Art Institute of Parsons School of Design',
#               'location': 'Baldessari'},
#              'Julian Opie': {'nationality': 'British',
#               'education': 'Goldsmiths, University of London',
#               'location': 'London'},
#              'John Chamberlain': {'education': 'the Art Institute of Chicago',
#               'location': 'New York',
#               'nationality': nan},
#              'Tenesh Webber': {'nationality': 'Canadian',
#               'location': 'NY',
#               'education': nan},
#              'Gudrun Mertes-Frady': {'nationality': 'Japanese',
#               'education': 'Rockefeller University',
#               'location': 'New York'},
#              'Gerhard Richter': {'nationality': 'Nazi',
#               'location': 'Dresden',
#               'education': nan},
#              'Bridget Riley': {'nationality': 'American',
#               'location': 'London',
#               'education': nan},
#              'Willem de Kooning': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Harland Miller': {'nationality': 'British',
#               'education': 'the Institute of Contemporary Art',
#               'location': 'UK'},
#              'Kiki Smith': {'nationality': 'German',
#               'location': 'Nuremberg',
#               'education': nan},
#              'Ugo Rondinone': {'nationality': 'Swiss',
#               'location': 'New York',
#               'education': nan},
#              'Georges Braque': {'nationality': 'Impressionist',
#               'location': 'Cubism',
#               'education': nan},
#              'Magnus Plessen': {'nationality': 'German',
#               'education': 'Art Institute of Chicago',
#               'location': 'Germany'},
#              'Ben Shahn': {'nationality': 'Lithuanian',
#               'education': nan,
#               'location': nan},
#              'Purvis Young': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Steve Kaufman': {'education': 'the School of Visual Arts',
#               'location': 'New York',
#               'nationality': nan},
#              'Simon Thompson': {'location': 'UK',
#               'nationality': nan,
#               'education': nan},
#              'Jay Rosenblum': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'John Kacere': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Steven Alexander': {'nationality': 'American',
#               'location': 'Texas',
#               'education': nan},
#              'Nathan Paddison': {'nationality': 'Australian',
#               'location': 'Graffiti',
#               'education': nan},
#              'Gunnar Norrman': {'nationality': 'Swedish',
#               'location': 'Sweden',
#               'education': nan},
#              'Capucine Safir': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Gene Davis': {'nationality': 'American',
#               'education': 'Catholic University',
#               'location': 'Washington'},
#              'Peter Hujar': {'nationality': 'Ukrainian',
#               'education': 'the School of Industrial Art',
#               'location': 'New York'},
#              'Herbert Bayer': {'nationality': 'Nazi',
#               'education': 'the Aspen Institute',
#               'location': 'Germany'},
#              'Max Papart': {'nationality': 'French',
#               'education': nan,
#               'location': nan},
#              'Paul Rousso': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Eduardo Sarabia': {'location': 'Los Angeles',
#               'nationality': nan,
#               'education': nan},
#              'Norman Bluhm': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Henry Moore': {'nationality': 'British',
#               'education': 'Leeds School of Art',
#               'location': 'Hertfordshire'},
#              'Sandra Chevrier': {'nationality': 'Canadian',
#               'location': 'Montreal',
#               'education': nan},
#              'Francine Tint': {'nationality': 'American',
#               'education': 'the New York Studio School of Drawing, Painting and Sculpture',
#               'location': 'New York'},
#              'Ayako Rokkaku': {'location': 'Tokyo',
#               'nationality': nan,
#               'education': nan},
#              'Miguel Berrocal': {'nationality': 'Spanish',
#               'education': nan,
#               'location': nan},
#              'Idris Habib': {'nationality': 'African-American',
#               'location': 'New York City',
#               'education': nan},
#              'Mark Beard': {'nationality': 'American',
#               'location': 'Salt Lake City',
#               'education': nan},
#              'Roby Dwi Antono': {'nationality': 'Indonesian',
#               'education': nan,
#               'location': nan},
#              'Demarcus McGaughey': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Frank Stella': {'nationality': 'American',
#               'education': 'the Princeton University',
#               'location': 'New York'},
#              'Nan Goldin': {'nationality': 'American',
#               'education': 'the Boston School',
#               'location': 'New York'},
#              'Christo and Jeanne-Claude': {'nationality': 'French',
#               'education': 'the University of Tunis',
#               'location': 'Christo'},
#              'Nick Gentry': {'education': 'the Francis Crick Institute',
#               'location': 'London',
#               'nationality': nan},
#              'Hans Hartung': {'education': 'School of Paris',
#               'nationality': 'French',
#               'location': 'Hartung'},
#              'Mimmo Rotella': {'nationality': 'Italian',
#               'education': 'Kansas City University',
#               'location': 'Rome'},
#              'Jean Dubuffet': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Friedel Dzubas': {'nationality': 'German',
#               'education': 'Cornell University',
#               'location': 'Berlin'},
#              'Romare Bearden': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Saul Steinberg': {'nationality': 'Jewish',
#               'education': nan,
#               'location': nan},
#              'Jack Youngerman': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'James Siena': {'nationality': 'American',
#               'education': 'Cornell University',
#               'location': 'New York'},
#              'Jannis Kounellis': {'nationality': 'Greek',
#               'location': 'Rome',
#               'education': nan},
#              'Arthur Dorval': {'nationality': 'French',
#               'location': 'France',
#               'education': nan},
#              'Anna Maria Maiolino': {'nationality': 'Italian',
#               'location': 'Brazil',
#               'education': nan},
#              'Ivan Argote': {'nationality': 'Colombian',
#               'education': 'the Arizona State University Art Museum',
#               'location': 'Paris'},
#              'Christopher Makos': {'nationality': 'American',
#               'location': 'Lowell',
#               'education': nan},
#              'Augustine Kofie': {'nationality': 'American',
#               'location': 'Los Angeles',
#               'education': nan},
#              'Ben Frost': {'nationality': 'Australian',
#               'education': 'the Institute of Modern Art',
#               'location': 'Brisbane'},
#              'Jasper Johns': {'education': 'the Parsons School of Design',
#               'nationality': 'Japanese',
#               'location': 'Jasper'},
#              'Sol LeWitt': {'education': 'Illustrators School',
#               'nationality': 'Cartoonist',
#               'location': 'New York'},
#              'Richard Serra': {'nationality': 'American',
#               'education': 'University of Yale',
#               'location': 'San Francisco'},
#              'Nobuyoshi Araki': {'nationality': 'Japanese',
#               'education': 'Chiba University',
#               'location': 'Tokyo'},
#              'Eric Fischl': {'education': 'California Institute of the Arts',
#               'nationality': 'American',
#               'location': 'New York City'},
#              'Eduardo Chillida': {'education': 'the University of Madrid',
#               'nationality': 'Basque',
#               'location': 'San Sebastián'},
#              'Mimmo Paladino': {'nationality': 'Paladino',
#               'location': 'Basel',
#               'education': nan},
#              'Helen Frankenthaler': {'nationality': 'American',
#               'education': 'the Dalton School',
#               'location': 'New York'},
#              'Mark Tobey': {'nationality': 'American',
#               'education': 'the Cornish School',
#               'location': 'Tobey'},
#              'Lucien Clergue': {'nationality': 'American',
#               'location': 'France',
#               'education': nan},
#              'Max Ernst': {'nationality': 'Surrealism',
#               'education': 'the University of Bonn',
#               'location': 'Paris'},
#              'Leonor Fini': {'nationality': 'Surrealist',
#               'location': 'Paris',
#               'education': nan},
#              'Jonas Wood': {'nationality': 'American',
#               'education': 'the University of Washington',
#               'location': 'Los Angeles'},
#              'Troy Brauntuch': {'nationality': 'American',
#               'education': 'the University of Texas',
#               'location': 'Jersey City'},
#              'The Connor Brothers': {'nationality': 'American',
#               'location': 'London',
#               'education': nan},
#              'Leonardo Nierman': {'nationality': 'Mexican',
#               'education': nan,
#               'location': nan},
#              'Ai Kijima': {'location': 'Japan',
#               'nationality': nan,
#               'education': nan},
#              'Claire Tabouret': {'nationality': 'French',
#               'location': 'Pertuis',
#               'education': nan},
#              'Oli Epp': {'nationality': 'Canadian',
#               'education': nan,
#               'location': nan},
#              'Javier Calleja': {'nationality': 'Spanish',
#               'education': nan,
#               'location': nan},
#              'Paul Wackers': {'nationality': 'American',
#               'location': 'New Haven',
#               'education': nan},
#              'Daniele Buetti': {'nationality': 'Swiss',
#               'location': 'Münster',
#               'education': nan},
#              'Henrik Eiben': {'nationality': 'American',
#               'education': 'Maryland Institute College of Art',
#               'location': 'Germany'},
#              'Juan Carlos Collada': {'nationality': 'American',
#               'location': 'Miami',
#               'education': nan},
#              'Julie Peppito': {'nationality': 'American',
#               'education': 'Alfred University',
#               'location': 'New York City'},
#              'Claes Oldenburg': {'nationality': 'American',
#               'education': 'the Art Institute of Chicago',
#               'location': 'Oldenburg'},
#              'Jenny Holzer': {'nationality': 'American',
#               'education': 'the Rhode Island School of Design',
#               'location': 'Truisms'},
#              'Larry Clark': {'nationality': 'American',
#               'education': 'the Layton School of Art',
#               'location': 'New York'},
#              'Massimo Vitali': {'nationality': 'Italian',
#               'location': 'Vitali',
#               'education': nan},
#              'Stephan Balkenhol': {'nationality': 'German',
#               'education': 'the University of Fine Arts of Hamburg',
#               'location': 'Germany'},
#              'Rufino Tamayo': {'nationality': 'Mexican',
#               'location': 'Tamayo',
#               'education': nan},
#              'Ross Bleckner': {'nationality': 'American',
#               'education': 'Steinhardt School of Culture, Education',
#               'location': 'New York'},
#              'Bernar Venet': {'nationality': 'French',
#               'education': 'Columbia University',
#               'location': 'New York'},
#              'Peter Beard': {'nationality': 'American',
#               'education': 'Yale University',
#               'location': 'New York'},
#              'Alphonse Mucha': {'nationality': 'American',
#               'location': 'Vienna',
#               'education': nan},
#              'Philip Pearlstein': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'CB Hoyo': {'nationality': nan,
#               'education': nan,
#               'location': nan},
#              'General Idea': {'nationality': 'Canadian',
#               'location': 'Toronto',
#               'education': nan},
#              'DALeast': {'nationality': 'Chinese',
#               'education': 'the Institute of Fine Arts',
#               'location': 'China'},
#              'Konrad Klapheck': {'nationality': 'German',
#               'location': 'Paris',
#               'education': nan},
#              'Louise Bourgeois': {'nationality': 'French',
#               'education': 'New York University Institute of Fine Arts',
#               'location': 'Bourgeois'},
#              'Terence Koh': {'nationality': 'Canadian',
#               'education': 'the\xa0Emily Carr Institute of Art and Design',
#               'location': 'Beijing'},
#              'Hebru Brantley': {'education': 'Clark Atlanta University',
#               'nationality': 'Japanese',
#               'location': 'Chicago'},
#              'Gilbert and George': {'education': 'School of Art',
#               'nationality': 'White',
#               'location': 'London'},
#              'Niki de Saint Phalle': {'nationality': 'French',
#               'education': 'Brearley School',
#               'location': 'Paris'},
#              'Jacques Lipchitz': {'nationality': 'Lithuanian',
#               'location': 'Paris',
#               'education': nan},
#              'Peter Blake': {'nationality': 'English',
#               'education': 'Nottingham Trent University',
#               'location': 'London'},
#              'Kenneth Noland': {'education': 'the Massachusetts Institute of Technology',
#               'nationality': 'American',
#               'location': 'Noland'},
#              'Liz Nielsen': {'location': 'Brooklyn',
#               'nationality': nan,
#               'education': nan},
#              'Elmgreen & Dragset': {'location': 'Copenhagen',
#               'nationality': nan,
#               'education': nan},
#              'Peter Anton': {'nationality': 'American',
#               'education': 'the University of Bridgeport',
#               'location': 'New York'},
#              'Takesada Matsutani': {'nationality': 'Japanese',
#               'location': 'Japan',
#               'education': nan},
#              'Lady Pink': {'nationality': 'English',
#               'location': 'Ambato',
#               'education': nan},
#              'Hilo Chen': {'nationality': 'Taiwanese',
#               'education': nan,
#               'location': nan},
#              'Lino Tagliapietra': {'nationality': 'Italian',
#               'location': 'Ohio',
#               'education': nan},
#              'Manfred Pernice': {'nationality': 'German',
#               'education': 'The Modern Institute',
#               'location': 'Berlin'},
#              'Lee Bae': {'nationality': 'Korean',
#               'education': 'Hongik University Graduate School of Art',
#               'location': 'Paris'},
#              'Matt Devine': {'nationality': 'American',
#               'location': 'USA',
#               'education': nan},
#              'Arthur Luiz Piza': {'nationality': 'Brazilian',
#               'location': 'Brazil',
#               'education': nan},
#              'John Little': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Adriana Oliver': {'nationality': 'Spanish',
#               'education': nan,
#               'location': nan},
#              'Pia Camil': {'nationality': 'Mexican',
#               'education': 'the Slade School of Fine Art',
#               'location': 'New York'},
#              'Marina Adams': {'nationality': 'American',
#               'education': 'Columbia University',
#               'location': 'New York'},
#              'Benny Andrews': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Adja Yunkers': {'nationality': 'American',
#               'location': 'Riga',
#               'education': nan},
#              'Richard Bernstein': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Christian Jankowski': {'nationality': 'German',
#               'education': nan,
#               'location': nan},
#              'Sheena Rose': {'nationality': 'Black',
#               'location': 'Barbados',
#               'education': nan},
#              'Jordan Kerwick': {'nationality': 'Australian',
#               'location': 'Melbourne',
#               'education': nan},
#              'Jon Burgerman': {'nationality': 'British',
#               'education': 'SVA School of Visual Arts',
#               'location': 'New York'},
#              'Ron English': {'nationality': 'American',
#               'location': 'POPaganda',
#               'education': nan},
#              'Paul Insect': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Swiz': {'nationality': 'French',
#               'location': 'Swiz',
#               'education': nan},
#              'Francis Bacon': {'nationality': 'Irish',
#               'location': 'London',
#               'education': nan},
#              'Christopher Wool': {'education': 'the New York Studio School',
#               'location': 'Boston',
#               'nationality': nan},
#              'Wayne Thiebaud': {'nationality': 'American',
#               'location': 'Thiebaud',
#               'education': nan},
#              'Martin Kippenberger': {'nationality': 'German',
#               'location': 'Berlin',
#               'education': nan},
#              'Anish Kapoor': {'education': 'the University of Oxford',
#               'nationality': 'Jewish',
#               'location': 'London'},
#              'Wade Guyton': {'nationality': 'Appropriation',
#               'education': 'Masters',
#               'location': 'Hammond'},
#              'Vik Muniz': {'nationality': 'Brazilian',
#               'location': 'Muniz',
#               'education': nan},
#              'Grayson Perry': {'nationality': 'Young British Artists',
#               'education': 'the University of the Arts',
#               'location': 'Chelmsford'},
#              'Peter Zimmermann': {'nationality': 'Photoshop',
#               'location': 'Germany',
#               'education': nan},
#              'Francisco Toledo': {'nationality': 'Zapotec',
#               'location': 'Toledo',
#               'education': nan},
#              'Olafur Eliasson': {'location': 'Moss',
#               'nationality': nan,
#               'education': nan},
#              'Conrad Marca-Relli': {'nationality': 'American',
#               'education': 'New York School Abstract',
#               'location': nan},
#              'Richard Hambleton': {'education': 'the San Francisco Institute of Art',
#               'nationality': 'Shadowman',
#               'location': 'New York City'},
#              'Mary Cassatt': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Milton Avery': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Abraham Walkowitz': {'nationality': 'Russian-American',
#               'location': 'New York',
#               'education': nan},
#              'Lawrence Schiller': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Pure Evil': {'nationality': 'British',
#               'location': 'Russia',
#               'education': nan},
#              'Nick Walker': {'nationality': 'French',
#               'location': 'Banksy',
#               'education': nan},
#              'Vhils': {'nationality': 'Portuguese',
#               'education': 'the University of the Arts - Central St Martins College of Art and Design',
#               'location': 'London'},
#              'George Condo': {'nationality': 'American',
#               'education': 'the University of Massachusetts',
#               'location': 'Condo'},
#              'Thomas Struth': {'nationality': 'German',
#               'education': 'The Art Institute of Chicago',
#               'location': 'Germany'},
#              'Martin Whatson': {'nationality': 'Norwegian',
#               'education': 'the Westerdals School of Communication',
#               'location': 'Paris'},
#              'Adolph Gottlieb': {'nationality': 'American',
#               'education': 'the National Institute of Arts and Letters',
#               'location': 'New York'},
#              'Georges Mathieu': {'nationality': 'French',
#               'education': 'the University of Lille',
#               'location': 'Boulogne'},
#              'Joan Mitchell': {'nationality': 'American',
#               'education': 'the Art Institute of Chicago',
#               'location': 'France'},
#              'Wolfgang Tillmans': {'nationality': 'Tillmans',
#               'location': 'London',
#               'education': nan},
#              'Lee Ufan': {'nationality': 'Korean',
#               'education': 'Tama Art University',
#               'location': 'Ufan'},
#              'Peter Halley': {'nationality': 'American',
#               'education': 'the University of New Orleans',
#               'location': 'New York'},
#              'Jack Pierson': {'nationality': 'American',
#               'education': 'the Boston School',
#               'location': 'MA'},
#              'Romero Britto': {'nationality': 'South American',
#               'education': 'the Catholic University of Pernambuco',
#               'location': 'Miami'},
#              'Louise Nevelson': {'nationality': 'American',
#               'education': 'the National Institutes of Health',
#               'location': 'New York'},
#              'Matteo Negri': {'nationality': 'Italian',
#               'location': 'Milan',
#               'education': nan},
#              'Adam Pendleton': {'nationality': 'African-American',
#               'education': 'Collegiate School',
#               'location': 'New York'},
#              'Richard Artschwager': {'nationality': 'American',
#               'education': 'Cornell University',
#               'location': 'Washington'},
#              'Giorgio de Chirico': {'nationality': 'Italian',
#               'location': 'Volos',
#               'education': nan},
#              'Chris Levine': {'nationality': 'Canadian',
#               'education': nan,
#               'location': nan},
#              'Angel Otero': {'nationality': 'Puerto Rican',
#               'education': 'the School of the Art Institute of Chicago',
#               'location': nan},
#              'Fiona Rae': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'George Grosz': {'nationality': 'German',
#               'location': 'Berlin',
#               'education': nan},
#              'Hermann Nitsch': {'nationality': 'Austrian',
#               'education': nan,
#               'location': nan},
#              'Hajime Sorayama': {'nationality': 'Japanese',
#               'education': 'the Chubi Central Art School',
#               'location': 'Imabari'},
#              'Reginald Marsh': {'nationality': 'American',
#               'location': 'Paris',
#               'education': nan},
#              'Carlos Cruz-Diez': {'nationality': 'French',
#               'location': 'Venezuela',
#               'education': nan},
#              'Henri Michaux': {'nationality': 'Belgian',
#               'education': 'the Art Institute of Chicago',
#               'location': 'New York'},
#              'Yinka Shonibare': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Waltercio Caldas': {'nationality': nan,
#               'education': nan,
#               'location': nan},
#              'Tomokazu Matsuyama': {'nationality': 'Japanese',
#               'education': nan,
#               'location': nan},
#              'Leonardo Drew': {'nationality': 'African American',
#               'location': 'Brooklyn',
#               'education': nan},
#              'Brian Calvin': {'nationality': nan,
#               'education': nan,
#               'location': nan},
#              'Budd Hopkins': {'nationality': 'American',
#               'education': 'Columbia University',
#               'location': 'New York'},
#              'Jerkface': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Pedro Friedeberg': {'nationality': 'Mexican',
#               'education': nan,
#               'location': nan},
#              'Peter Lik': {'nationality': 'Australian',
#               'education': nan,
#               'location': nan},
#              'Tony Marsh': {'nationality': 'American',
#               'location': 'Long Beach',
#               'education': nan},
#              'Lauren Mabry': {'nationality': 'American',
#               'location': 'Madison',
#               'education': nan},
#              'Tamara Dean': {'nationality': 'Australian',
#               'education': 'the University of Western Sydney',
#               'location': 'Australia'},
#              'Tunji Adeniyi-Jones': {'nationality': 'British',
#               'location': 'Yoruba',
#               'education': nan},
#              'Pez': {'nationality': 'French',
#               'location': 'Nantes',
#               'education': nan},
#              'Raphael Macek': {'nationality': 'Brazilian',
#               'education': nan,
#               'location': nan},
#              'Richard Perry': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Fritz Scholder': {'nationality': nan,
#               'education': nan,
#               'location': nan},
#              'Byron Browne': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Calman Shemi': {'nationality': 'Argentinian',
#               'location': 'Mendoza',
#               'education': nan},
#              'Nina Chanel Abney': {'nationality': 'American',
#               'location': 'Chicago',
#               'education': nan},
#              'Derrick Velasquez': {'nationality': 'American',
#               'education': 'Ohio State University',
#               'location': 'Santa Barbara'},
#              'Dan Lam': {'nationality': 'American',
#               'location': 'Dallas',
#               'education': nan},
#              'Robert Kelly': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Jeff Kellar': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Otis Kwame Kye Quaicoe': {'nationality': 'Ghanaian',
#               'location': 'Portland',
#               'education': nan},
#              'TIDE': {'nationality': 'Japanese',
#               'education': nan,
#               'location': nan},
#              'Tomoko Nagai': {'nationality': 'Japanese',
#               'location': 'Aichi Prefecture',
#               'education': nan},
#              'Madeline Donahue': {'nationality': 'American',
#               'education': 'Tufts University & The School of the Museum of Fine Arts',
#               'location': 'Brooklyn'},
#              'Futura': {'nationality': 'Spaceship',
#               'location': 'New York',
#               'education': nan},
#              'Jean-Michel Basquiat': {'nationality': 'African-Caribbean',
#               'location': 'Manhattan',
#               'education': nan},
#              'Fin DAC': {'nationality': 'Aesthetics',
#               'location': 'London',
#               'education': nan},
#              'Cleon Peterson': {'nationality': 'American',
#               'location': 'Los Angeles',
#               'education': nan},
#              'Barbara Kruger': {'nationality': 'American',
#               'education': 'the University of California',
#               'location': 'New York'},
#              'Joseph Kosuth': {'education': 'Oxford University',
#               'nationality': 'American',
#               'location': 'Kosuth'},
#              'Brian Dettmer': {'nationality': 'Smithsonian',
#               'location': 'US',
#               'education': nan},
#              'Joseph Beuys': {'nationality': 'Dutch',
#               'education': 'the University of Posen',
#               'location': 'Germany'},
#              'Zhang Xiaogang': {'nationality': 'Chinese',
#               'location': 'China',
#               'education': nan},
#              'Marino Marini': {'nationality': 'Italian',
#               'location': 'Milan',
#               'education': nan},
#              'Russell Young': {'nationality': 'British American',
#               'location': 'Los Angeles',
#               'education': nan},
#              'Donald Baechler': {'nationality': 'American',
#               'education': 'Maryland Institute College of Art',
#               'location': 'New York'},
#              'Gavin Turk': {'nationality': 'British',
#               'education': 'Chelsea School of Art',
#               'location': 'London'},
#              'Miaz Brothers': {'nationality': 'Italian',
#               'education': 'European Institute of Design',
#               'location': 'Cyan'},
#              'Alec Soth': {'nationality': 'American',
#               'education': 'the Minneapolis Institute of Arts',
#               'location': 'Mississippi'},
#              'Frank Auerbach': {'nationality': 'British',
#               'education': 'St. Marin’s School of Art',
#               'location': 'London'},
#              'Charles Hinman': {'nationality': 'American',
#               'location': 'Syracuse',
#               'education': nan},
#              'Lee Friedlander': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Joel Shapiro': {'nationality': 'American',
#               'location': 'New York City',
# ...
#               'education': nan},
#              'Wes Lang': {'nationality': 'American',
#               'location': 'Cy Twombly',
#               'education': nan},
#              'Levalet': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Liu Bolin': {'nationality': 'Chinese',
#               'location': 'China',
#               'education': nan},
#              'Katrin Fridriks': {'nationality': 'Japanese',
#               'location': 'Iceland',
#               'education': nan},
#              'Pejac': {'nationality': 'Spanish',
#               'location': 'Hong Kong',
#               'education': nan},
#              'Tom Sachs': {'nationality': 'American',
#               'education': 'Architectural Association School of Architecture',
#               'location': 'New York'},
#              'David Ostrowski': {'nationality': 'German',
#               'location': 'USA',
#               'education': nan},
#              'Cindy Sherman': {'education': 'the State University of New York',
#               'nationality': 'Italian',
#               'location': 'New York'},
#              'David LaChapelle': {'nationality': 'American',
#               'education': 'the School of Visual Arts',
#               'location': 'New York'},
#              'Helmut Newton': {'nationality': 'German',
#               'education': 'the American Institute of Graphic Arts',
#               'location': 'Newton'},
#              'Mark Ryden': {'nationality': 'American',
#               'location': 'Ryden',
#               'education': nan},
#              'Andreas Gursky': {'nationality': 'British',
#               'education': 'Düsseldorf School',
#               'location': 'Leipzig'},
#              'Martin Parr': {'education': 'the University of Ulster',
#               'nationality': 'Barbican',
#               'location': 'England'},
#              'Bambi': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Georg Baselitz': {'nationality': 'German',
#               'location': 'Germany',
#               'education': nan},
#              'Antony Gormley': {'nationality': 'British',
#               'education': 'the Royal Institute of British Architects',
#               'location': 'London'},
#              'Tony Cragg': {'education': 'Wimbledon School of Art',
#               'nationality': 'British',
#               'location': 'Britain'},
#              'Marc Quinn': {'nationality': 'Greek',
#               'location': 'London',
#               'education': nan},
#              'Maurizio Cattelan': {'nationality': 'Italian',
#               'location': 'Italy',
#               'education': nan},
#              'Raymond Pettibon': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Robert Longo': {'education': 'the University of North Texas',
#               'nationality': 'American',
#               'location': 'New York'},
#              'Joe Bradley': {'nationality': 'American',
#               'education': 'the Rhode Island School of Design',
#               'location': 'Minimalism'},
#              'Gary Baseman': {'nationality': 'American',
#               'location': 'Los Angeles',
#               'education': nan},
#              'Eddie Martinez': {'location': 'Martinez',
#               'nationality': nan,
#               'education': nan},
#              'Ernesto Neto': {'nationality': 'Brazilian',
#               'education': 'the School of Visual Arts of Parque Lage',
#               'location': 'Rio de Janeiro'},
#              'Vija Celmins': {'nationality': 'Latvian-American',
#               'education': 'John Herron School of Art',
#               'location': 'New York City'},
#              'Alex Prager': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Per Kirkeby': {'education': 'Copenhagen University',
#               'nationality': 'Tachism',
#               'location': 'Germany'},
#              'A.R. Penck': {'nationality': 'German',
#               'location': 'Berlin',
#               'education': nan},
#              'Laurie Simmons': {'nationality': 'American',
#               'education': 'the Tyler School of Art',
#               'location': 'New York'},
#              'Franz West': {'nationality': 'Austrian',
#               'location': 'Vienna',
#               'education': nan},
#              'Jonathan Meese': {'nationality': 'Neo',
#               'location': 'Hamburg',
#               'education': nan},
#              'Marcel Dzama': {'nationality': 'Surrealist',
#               'education': 'the University of Manitoba',
#               'location': 'New York'},
#              'Andy Goldsworthy': {'education': 'Stanford University',
#               'nationality': 'British',
#               'location': 'New York'},
#              'Mr.': {'nationality': 'Japanese',
#               'education': 'Sokei Art School',
#               'location': 'Murakami'},
#              'The London Police': {'location': 'Amsterdam',
#               'nationality': nan,
#               'education': nan},
#              'Yang Maoyuan': {'nationality': 'Chinese',
#               'location': 'China',
#               'education': nan},
#              'Gregory Crewdson': {'nationality': 'American',
#               'education': 'the University of Salamanca',
#               'location': 'Brooklyn'},
#              'Leonora Carrington': {'nationality': 'Celtic',
#               'location': 'Mexico',
#               'education': nan},
#              'Daido Moriyama': {'nationality': 'Japanese',
#               'location': 'Japan',
#               'education': nan},
#              'Carl Andre': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Mambo': {'nationality': 'Parisian',
#               'location': 'Paris',
#               'education': nan},
#              'Ansel Adams': {'nationality': 'American',
#               'location': 'Grand Canyon',
#               'education': nan},
#              'Hans Burkhardt': {'nationality': 'Swiss',
#               'education': 'California State University',
#               'location': 'Basel'},
#              'Cleve Gray': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'David Simpson': {'nationality': 'American',
#               'education': 'the University of California, Barkeley',
#               'location': nan},
#              'Douglas Gordon': {'nationality': 'Scottish',
#               'education': 'Slade School of Fine Art',
#               'location': 'Glasgow'},
#              'Arnaldo Pomodoro': {'nationality': 'Italian',
#               'education': 'Stanford University',
#               'location': 'Milan'},
#              'Ernst Haas': {'nationality': 'Austrian-American',
#               'location': 'Vienna',
#               'education': nan},
#              'David Salle': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'William T. Wiley': {'nationality': 'American',
#               'location': 'Bedford',
#               'education': nan},
#              'Michael Goldberg': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Alberto Giacometti': {'nationality': 'Surrealism',
#               'location': 'Paris',
#               'education': nan},
#              'Ben Nicholson': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Maria Helena Vieira da Silva': {'nationality': 'Portuguese-French',
#               'location': 'Lisbon',
#               'education': nan},
#              'Giorgio Morandi': {'nationality': 'Italian',
#               'location': 'Bologna',
#               'education': nan},
#              'Anton Henning': {'nationality': 'German',
#               'education': nan,
#               'location': nan},
#              'Rachel Whiteread': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Nicole Eisenman': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Jean Arp': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'John Hoyland': {'nationality': 'British',
#               'location': 'London',
#               'education': nan},
#              'Frantisek Drtikol': {'nationality': 'Czech',
#               'education': nan,
#               'location': nan},
#              'Sarah Morris': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Michael Eastman': {'nationality': 'American',
#               'location': 'Havana',
#               'education': nan},
#              'Roni Horn': {'nationality': 'American',
#               'education': 'Institute of Contemporary Art',
#               'location': 'New York'},
#              'George Segal': {'nationality': 'American',
#               'education': "Princeton University's",
#               'location': 'Bronx'},
#              'Jack Whitten': {'nationality': 'American',
#               'location': 'Bessemer',
#               'education': nan},
#              'Sarah Lucas': {'nationality': 'British',
#               'education': 'the Institute of Contemporary Art',
#               'location': 'London'},
#              'Shozo Shimamoto': {'nationality': 'Japanese',
#               'education': 'Kansui Gakuin University',
#               'location': 'Gutai'},
#              'Auguste Rodin': {'nationality': 'French',
#               'education': nan,
#               'location': nan},
#              'Olivier Mosset': {'nationality': 'Swiss',
#               'location': 'Switzerland',
#               'education': nan},
#              'Elizabeth Murray': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'George Tooker': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Osvaldo Borsani': {'nationality': 'Swiss',
#               'education': nan,
#               'location': nan},
#              'Diego Rivera': {'nationality': 'Mexican',
#               'education': 'the California School of Fine Arts',
#               'location': 'Mexico'},
#              'Harry Bertoia': {'nationality': 'Italian',
#               'education': nan,
#               'location': nan},
#              'Adam Lister': {'nationality': 'American',
#               'education': 'School of Visual Arts',
#               'location': 'New York'},
#              'Bortusk Leer': {'nationality': 'Slovenian',
#               'location': 'London',
#               'education': nan},
#              'Gonzalo Fuenmayor': {'nationality': 'Colombian',
#               'education': 'School of the Museum of Fine Arts',
#               'location': 'Boston'},
#              'Pino Pinelli': {'nationality': 'Italian',
#               'education': 'the Institute of Italian Culture',
#               'location': 'Milan'},
#              'Larry Bell': {'nationality': 'American',
#               'location': 'Taos',
#               'education': nan},
#              'Doze Green': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Mau Mau': {'nationality': 'British',
#               'education': nan,
#               'location': nan},
#              'Zest': {'nationality': 'French',
#               'location': 'France',
#               'education': nan},
#              'Matthew Craven': {'nationality': 'American',
#               'education': 'the School of Visual Arts',
#               'location': 'New York'},
#              'Bradley Hart': {'nationality': 'Canadian',
#               'education': 'the University of Toronto',
#               'location': 'Toronto'},
#              'Jorinde Voigt': {'education': 'the Berlin University of the Arts',
#               'location': 'New York',
#               'nationality': nan},
#              'Alexander Liberman': {'nationality': 'Russian-American',
#               'location': 'Kiev',
#               'education': nan},
#              'Prefab77': {'nationality': 'British',
#               'location': 'UK',
#               'education': nan},
#              'Julio Le Parc': {'nationality': 'Argentinian',
#               'education': 'the School of Fine Arts',
#               'location': 'Argentina'},
#              'OG Slick': {'location': 'Los Angeles',
#               'nationality': nan,
#               'education': nan},
#              'Jo Di Bona': {'nationality': 'French',
#               'location': 'VF',
#               'education': nan},
#              'Ettore Sottsass': {'nationality': 'Italian',
#               'education': nan,
#               'location': nan},
#              'Ossip Zadkine': {'nationality': 'Russian',
#               'location': 'France',
#               'education': nan},
#              'Eyvind Earle': {'nationality': 'American',
#               'education': 'Arizona State University Museum',
#               'location': 'New York City'},
#              'Shara Hughes': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Walter Robinson': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Snik': {'nationality': 'Italian',
#               'location': 'UK',
#               'education': nan},
#              'John Coplans': {'location': 'London',
#               'nationality': nan,
#               'education': nan},
#              'Greg Guillemin': {'nationality': 'French',
#               'location': 'Paris',
#               'education': nan},
#              'Leonardo Cremonini': {'nationality': 'Italian',
#               'location': 'the United States',
#               'education': nan},
#              'Josep Guinovart': {'location': 'Barcelona',
#               'nationality': nan,
#               'education': nan},
#              'Mr Doodle': {'nationality': 'British',
#               'location': 'Doodleland',
#               'education': nan},
#              'Angelo Accardi': {'nationality': 'Italian',
#               'education': nan,
#               'location': nan},
#              'Karl Lagasse': {'nationality': 'French',
#               'education': nan,
#               'location': nan},
#              'Yuri Kuper': {'nationality': 'Russian',
#               'education': nan,
#               'location': nan},
#              'Jimmie Durham': {'nationality': 'American',
#               'education': 'Institute of Contemporary Arts',
#               'location': 'Houston'},
#              'Max Ingrand': {'nationality': 'French',
#               'education': nan,
#               'location': nan},
#              'Shadi Ghadirian': {'nationality': 'Iranian',
#               'education': 'Azad University',
#               'location': 'Tehran'},
#              'Kim MacConnel': {'nationality': 'American',
#               'location': 'Oklahoma City',
#               'education': nan},
#              'Florian Eymann': {'nationality': 'French',
#               'location': 'Auxerre',
#               'education': nan},
#              'Add Fuel': {'nationality': 'Portuguese',
#               'location': 'Machado',
#               'education': nan},
#              'Rex Ashlock': {'nationality': 'American',
#               'location': 'New York',
#               'education': nan},
#              'Antoine Poncet': {'nationality': 'Swiss',
#               'location': 'Paris',
#               'education': nan},
#              'William Gropper': {'nationality': 'American',
#               'education': nan,
#               'location': nan},
#              'Zhoujie Zhang': {'nationality': 'Chinese',
#               'education': nan,
#               'location': nan},
#              'Francisca Sutil': {'nationality': 'Chilean',
#               'education': nan,
#               'location': nan},
#              'Jiha Moon': {'nationality': 'Korean',
#               'location': 'Atlanta',
#               'education': nan},
#              'Derrick Adams': {'nationality': 'American',
#               'location': 'Baltimore',
#               'education': nan}})

# %%
artist_profiles_list = []
for artist, profile in artist_profiles.items():
    temp = [profile['nationality'], profile['education'], profile['location']]
    row = [artist]+temp
    artist_profiles_list.append(row)

# %%
artist_profiles_df = pd.DataFrame(artist_profiles_list, columns = ['artist_name', 'nationality', 'education', 'location'])

# %%
artist_profiles_df.head()
# Out:
#        artist_name nationality                      education  location
# 0   David Shrigley     British                            NaN   Glasgow
# 1     David Yarrow     British       the Edinburgh University   Glasgow
# 2  Dan Christensen    American  the Kansas City Art Institute    Denver
# 3             KAWS    American      the School of Visual Arts     Tokyo
# 4      Andy Warhol    American     Carnegie-Mellon University  New York

# %% [markdown]
# # Merge with final dataset

# %%
final_df = pd.read_csv("../FinalDataSetCreation/FinalDataSet.csv")

# %%
final_df.head()
# Out:
#            id     media                                                url  \
# 0  painting15  painting  https://www.artsy.net/artwork/hebru-brantley-d...
# 1  painting37  painting  https://www.artsy.net/artwork/miaz-brothers-ma...
# 2  painting41  painting  https://www.artsy.net/artwork/sandra-chevrier-...
# 3  painting45  painting  https://www.artsy.net/artwork/florian-eymann-b...
# 4  painting52  painting  https://www.artsy.net/artwork/miaz-brothers-a-...
#
#        artist_name                                    artist_url  \
# 0   Hebru Brantley   https://www.artsy.net/artist/hebru-brantley
# 1    Miaz Brothers    https://www.artsy.net/artist/miaz-brothers
# 2  Sandra Chevrier  https://www.artsy.net/artist/sandra-chevrier
# 3   Florian Eymann   https://www.artsy.net/artist/florian-eymann
# 4    Miaz Brothers    https://www.artsy.net/artist/miaz-brothers
#
#                                           work_name  work_year  \
# 0  Death Of The Black Fairy, The Great Debate Pt. 5       2020
# 1                                           Maestro       2022
# 2        La cage où le brouillard traverse l’esprit       2017
# 3                              BAYC Clueless Sailor       2022
# 4                             A Promising Young Man       2022
#
#                          media_long                          dimension  \
# 0  Acrylic & Diamond Dust on Canvas      60 × 60 in | 152.4 × 152.4 cm
# 1                 Acrylic on canvas  40 1/5 × 29 9/10 in | 102 × 76 cm
# 2                     Oil on canvas        12 × 12 in | 30.5 × 30.5 cm
# 3                     Oil on canvas   43 × 34 1/2 in | 109.2 × 87.6 cm
# 4                 Acrylic on canvas       48 × 35 4/5 in | 122 × 91 cm
#
#                 gallery_name  \
# 0      Corridor Contemporary
# 1             Maddox Gallery
# 2  West Chelsea Contemporary
# 3              Avant Gallery
# 4             Maddox Gallery
#
#                                          gallery_url    bid     price  \
# 0  https://www.artsy.net/partner/corridor-contemp...  False  125000.0
# 1       https://www.artsy.net/partner/maddox-gallery  False   17500.0
# 2  https://www.artsy.net/partner/west-chelsea-con...  False    5000.0
# 3        https://www.artsy.net/partner/avant-gallery  False   11000.0
# 4       https://www.artsy.net/partner/maddox-gallery  False   17500.0
#
#                                              img_url  \
# 0  https://d7hftxdivxxvm.cloudfront.net?resize_to...
# 1  https://d7hftxdivxxvm.cloudfront.net?resize_to...
# 2  https://d7hftxdivxxvm.cloudfront.net?resize_to...
# 3  https://d7hftxdivxxvm.cloudfront.net?resize_to...
# 4  https://d7hftxdivxxvm.cloudfront.net?resize_to...
#
#                                             full_bio          artist_website  \
# 0  Hebru Brantley, a Bronzeville-native living an...   www.hebrubrantley.com
# 1  The Miaz Brothers present a radical new take o...    www.miazbrothers.com
# 2  Sandra Chevrier is a Canadian contemporary art...  www.sandrachevrier.com
# 3  Florian Eymann is a self-taught French artist ...   www.florianeymann.com
# 4  The Miaz Brothers present a radical new take o...    www.miazbrothers.com
#
#                                         artist_ins
# 0   https://www.instagram.com/hebrubrantley/?hl=en
# 1    https://www.instagram.com/miazbrothers/?hl=en
# 2  https://www.instagram.com/sandrachevrier/?hl=en
# 3   https://www.instagram.com/florianeymann/?hl=en
# 4    https://www.instagram.com/miazbrothers/?hl=en

# %%
final_merged_df = final_df.merge(artist_profiles_df, on="artist_name")

# %%
final_merged_df.head()
# Out:
#                id        media  \
# 0      painting15     painting
# 1       prints369       prints
# 2       prints826       prints
# 3  photography133  photography
# 4      painting37     painting
#
#                                                  url     artist_name  \
# 0  https://www.artsy.net/artwork/hebru-brantley-d...  Hebru Brantley
# 1  https://www.artsy.net/artwork/hebru-brantley-f...  Hebru Brantley
# 2  https://www.artsy.net/artwork/hebru-brantley-m...  Hebru Brantley
# 3  https://www.artsy.net/artwork/hebru-brantley-n...  Hebru Brantley
# 4  https://www.artsy.net/artwork/miaz-brothers-ma...   Miaz Brothers
#
#                                     artist_url  \
# 0  https://www.artsy.net/artist/hebru-brantley
# 1  https://www.artsy.net/artist/hebru-brantley
# 2  https://www.artsy.net/artist/hebru-brantley
# 3  https://www.artsy.net/artist/hebru-brantley
# 4   https://www.artsy.net/artist/miaz-brothers
#
#                                           work_name  work_year  \
# 0  Death Of The Black Fairy, The Great Debate Pt. 5       2020
# 1                                     Flower N Word       2022
# 2                                         Monoprint       2017
# 3                                      Night Flight       2021
# 4                                           Maestro       2022
#
#                                           media_long  \
# 0                   Acrylic & Diamond Dust on Canvas
# 1  22-color Hand-Pulled Screen Print, Saunders Wa...
# 2  Hand-Pulled Screen Print on Mohawk Superfine U...
# 3  Digital print with screen printed glow in the ...
# 4                                  Acrylic on canvas
#
#                            dimension           gallery_name  ...  \
# 0      60 × 60 in | 152.4 × 152.4 cm  Corridor Contemporary  ...
# 1       40 × 30 in | 101.6 × 76.2 cm          Pinto Gallery  ...
# 2          24 × 18 in | 61 × 45.7 cm               MODCLAIR  ...
# 3        29 × 36 in | 73.7 × 91.4 cm    Heritage: Urban Art  ...
# 4  40 1/5 × 29 9/10 in | 102 × 76 cm         Maddox Gallery  ...
#
#                       education  location   color1   color2   color3   color4  \
# 0      Clark Atlanta University   Chicago  #E7DFCC  #A69784  #403931  #877C76
# 1      Clark Atlanta University   Chicago      NaN      NaN      NaN      NaN
# 2      Clark Atlanta University   Chicago      NaN      NaN      NaN      NaN
# 3      Clark Atlanta University   Chicago      NaN      NaN      NaN      NaN
# 4  European Institute of Design      Cyan  #181A15  #2F342E  #43492F  #B8A36C
#
#   color_group1 color_group2 color_group3 color_group4
# 0           69           24          192          246
# 1           -1           -1           -1           -1
# 2           -1           -1           -1           -1
# 3           -1           -1           -1           -1
# 4          121          280          147           12
#
# [5 rows x 28 columns]

# %%
color_group_df = pd.read_csv("../Final_Streamlit/data/Final_Dataset_w_colorgroup.csv")

# %%
color_group_df = color_group_df[['id', 'color1','color2', 'color3', 'color4', 'color_group1', 'color_group2', 'color_group3', 'color_group4']]

# %%
final_merged_df = final_merged_df.merge(color_group_df, on="id")

# %%
final_merged_df.to_csv("../FinalDataSetCreation/FinalDataset_with_all.csv")

# %% [markdown]
# # Manual check

# %%
random_checks = []
for idx in random_idx:
    artist = artist_profiles_list[idx]
    random_checks.append((artist, artist_profiles[artist]))

# %%
random_checks
# Out:
# [('Stan Maksun', {'nationality': 'American'}),
#  ('Julian Stanczak',
#   {'nationality': 'American',
#    'education': 'School of Art and Architecture',
#    'location': 'Poland'}),
#  ('Ernie Barnes', {'nationality': 'American'}),
#  ('Jim Perry', {'nationality': 'American'}),
#  ('Lois Gross Smiley', {'nationality': 'American'}),
#  ('Bisser', {'nationality': 'Belgian', 'location': 'Ibiza'}),
#  ('Jeffrey Maron', {'nationality': 'American', 'location': 'Watercolor'}),
#  ('Jean Louis Liberte', {'nationality': 'French'}),
#  ('Oyvind Fahlstrom', {'nationality': 'Swedish'}),
#  ('Donald Lipski', {'nationality': 'American'}),
#  ('Manfred Pernice', {'nationality': 'German', 'location': 'Berlin'}),
#  ('Leonetto Cappiello', {'nationality': 'French', 'location': 'France'}),
#  ('Mathew Hale',
#   {'nationality': 'British',
#    'education': 'Harvard University',
#    'location': 'Berlin'}),
#  ('Evan Hecox', {'location': 'Colorado'}),
#  ('Natalya Zaloznaya',
#   {'education': 'the Belorussian State University of Theatre and\nArts',
#    'location': 'Minsk'}),
#  ('Jeff Kellar', {'nationality': 'American'}),
#  ('Andre Minaux', {'nationality': 'French', 'location': 'Paris'}),
#  ('Toland Sand', {'nationality': 'American'}),
#  ('Ray Charles White', {'nationality': 'Canadian', 'location': 'New York'}),
#  ('Audrey Stone', {'location': 'New York'}),
#  ('Julian Opie',
#   {'nationality': 'British',
#    'education': 'Goldsmiths, University of London',
#    'location': 'London'}),
#  ('Roberto De Lamonica', {'nationality': 'Brazilian'}),
#  ('Leslie Sheryll', {'nationality': 'American'}),
#  ('S.P. Jayakar', {'nationality': 'South Indian', 'location': 'India'}),
#  ('Albert Llobet Portell',
#   {'education': 'the University of Southampton', 'location': 'Barcelona'}),
#  ('Olivier Mosset', {'nationality': 'Swiss', 'location': 'Switzerland'}),
#  ('Chen Ke', {'nationality': 'Chinese', 'location': 'China'}),
#  ('Sam Bolton', {'location': 'New York City'}),
#  ('Gavin Turk',
#   {'nationality': 'British',
#    'education': 'Chelsea School of Art',
#    'location': 'London'}),
#  ('Macha Poynder', {'nationality': 'Russian', 'location': 'Paris'}),
#  ('Nuge',
#   {'education': 'Roger Williams University', 'location': 'Rhode Island'}),
#  ('Friedrich Heinrich Fuger', {'nationality': 'German', 'location': 'Vienna'}),
#  ('Genieve Figgis',
#   {'nationality': 'Irish',
#    'education': 'Gorey School of Art',
#    'location': 'New York'}),
#  ('Robert Dash',
#   {'education': 'the University of New Mexico',
#    'nationality': 'American',
#    'location': 'Long Island'}),
#  ('Gregor Hildebrandt',
#   {'nationality': 'German',
#    'education': 'the University of Mainz',
#    'location': 'Germany'}),
#  ('Toland Sand', {'nationality': 'American'}),
#  ('Irene Nelson', {'nationality': 'American', 'location': 'California'}),
#  ('Erte', {'nationality': 'Russian', 'location': 'Russia'}),
#  ('Niki de Saint Phalle',
#   {'nationality': 'French',
#    'education': 'Brearley School',
#    'location': 'Paris'}),
#  ('Daze',
#   {'education': 'the Bronx Museum Hofstra University',
#    'nationality': 'Ellis',
#    'location': 'New York'}),
#  ('Corinne Vogel', {'nationality': 'Swiss', 'location': 'Thun'}),
#  ('Alex Prager', {'nationality': 'American', 'location': 'New York'}),
#  ('Elizabeth Gourlay',
#   {'nationality': 'American',
#    'education': 'The National Academy Museum & School',
#    'location': 'New York'}),
#  ('Sharon Brill', {'nationality': 'Israeli'}),
#  ('Otis Hope Carey', {'nationality': 'Australian'}),
#  ('Jane Hammond',
#   {'nationality': 'American',
#    'education': 'University of Wisconsin',
#    'location': 'New York'}),
#  ('Wayne Ensrud', {'nationality': 'American'}),
#  ('Julius Heinemann',
#   {'nationality': 'German',
#    'education': 'Folkwang University of Arts',
#    'location': 'London'}),
#  ('Robert van Bolderick', {'nationality': 'Swedish', 'location': 'Stockholm'}),
#  ('Bezt', {'nationality': 'Polish', 'location': 'Turek'}),
#  ('Erro',
#   {'nationality': 'European',
#    'education': 'the Reykjavík School of Visual Art',
#    'location': 'Paris'}),
#  ('Pamela Council', {'nationality': 'American'}),
#  ('Dennis Hare', {'nationality': 'American', 'location': 'California'}),
#  ('Jorge Mendez Blake', {'nationality': 'Mexican', 'location': 'Guadalajara'}),
#  ('Adam Lister',
#   {'nationality': 'American',
#    'education': 'School of Visual Arts',
#    'location': 'New York'}),
#  ('Caroline Vis', {'location': 'Netherlands'}),
#  ('Stephen Maine',
#   {'nationality': 'American',
#    'education': 'the State University of New York at Purchase',
#    'location': 'Maine'}),
#  ('Michael Barringer', {'nationality': 'American'}),
#  ('Nalini Malani',
#   {'nationality': 'Indian',
#    'education': 'Jamsetjee Jeejebhoy School of Art',
#    'location': 'Mumbai'}),
#  ('Hilo Chen', {'nationality': 'Taiwanese'}),
#  ('Manuel Merida', {'nationality': 'Venezuelan', 'location': 'Paris'}),
#  ('Sweetieboosh', {'nationality': 'American'}),
#  ('Gabor Peterdi',
#   {'nationality': 'Hungarian', 'education': 'Yale University'}),
#  ('Betty Merken', {'nationality': 'American'}),
#  ('Anya Spielman',
#   {'nationality': 'American',
#    'education': 'the University of California at Davis',
#    'location': 'California'}),
#  ('Frederick J. Brown', {'nationality': 'American'}),
#  ('Ray Parker',
#   {'education': 'the\xa0University of Minnesota\xa0',
#    'location': 'Beresford'}),
#  ('Roni Horn',
#   {'nationality': 'American',
#    'education': 'the University of Akureyri',
#    'location': 'New York'}),
#  ('Donald Saff', {'nationality': 'American'}),
#  ('Johnny Abrahams', {'nationality': 'American'}),
#  ('Dabs Myla', {'nationality': 'Vans', 'location': 'Los Angeles'}),
#  ('Alexander Liberman',
#   {'nationality': 'Russian-American', 'location': 'Kiev'}),
#  ('OG Slick', {'location': 'Los Angeles'}),
#  ('Charis Entwisle', {'nationality': 'British', 'location': 'North\nLondon'}),
#  ('Roy Ahlgren', {'nationality': 'American'}),
#  ('Dmitri Wright', {'nationality': 'American', 'location': 'France'}),
#  ('Dannielle Tegeder', {'nationality': 'American', 'location': 'Brooklyn'}),
#  ('Lothar Charoux', {'nationality': 'Austrian', 'location': 'Vienna'}),
#  ('Jorge Macchi',
#   {'nationality': 'Argentinian',
#    'education': 'the National School of Fine Arts',
#    'location': 'Spain'}),
#  ('Francisco Toledo', {'nationality': 'Zapotec', 'location': 'Toledo'}),
#  ('Julien Delagrange',
#   {'nationality': 'Belgian',
#    'education': 'Ghent University',
#    'location': 'Kortrijk'}),
#  ('The London Police', {'location': 'Amsterdam'}),
#  ('Roger Brown',
#   {'nationality': 'American',
#    'education': 'the School of the Art Institute of Chicago',
#    'location': 'Chicago'}),
#  ('Bambi', {'nationality': 'British', 'location': 'London'}),
#  ('Perino e Vele', {'nationality': 'Italian'}),
#  ('Budd Hopkins',
#   {'nationality': 'American',
#    'education': 'Columbia University',
#    'location': 'New York'}),
#  ('Tacita Dean', {'nationality': 'British'}),
#  ('Katharina Grosse', {'nationality': 'German', 'location': 'New York'}),
#  ('Raul de la Torre', {'nationality': 'Spanish'}),
#  ('Stephan Baumkotter', {'nationality': 'German', 'location': 'Germany'}),
#  ('Paul Bloch', {'nationality': 'American', 'location': 'Limestone'}),
#  ('Mark Ryden', {'nationality': 'American', 'location': 'Ryden'}),
#  ('Jose Lerma',
#   {'nationality': 'Spanish',
#    'education': 'Painting University of Wisconsin-Madison',
#    'location': 'New Orleans'}),
#  ('Will Boone', {'nationality': 'American', 'location': 'London'}),
#  ('Pierre Clerk', {'nationality': 'Canadian'}),
#  ('Deborah Bigeleisen', {'nationality': 'American'}),
#  ('Julio Le Parc',
#   {'nationality': 'Argentinian',
#    'education': 'the School of Fine Arts',
#    'location': 'Argentina'}),
#  ('Jose Leon Cerrillo',
#   {'nationality': 'Mexican',
#    'education': 'Columbia University',
#    'location': 'US'}),
#  ('Santiago Medina',
#   {'nationality': 'Colombian-American', 'location': 'Medina'}),
#  ('Andrew Davis', {'location': 'Staunton'})]

# %%
print(full_bio_df[full_bio_df['artist_names'] == "Stan Maksun"])
# Out:
#       Unnamed: 0 artist_names  \
# 1265        1265  Stan Maksun
#
#                                               full_bios
# 1265  Combining elements of horror,\nfantasy and sci...
